# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Thi Thanh Chuong**
#
# I'm a software engineer.

# %% [markdown]
# *I am interested in data science because i love to explore data and built model predict base data.*

# %% [markdown]
# ### I will code function ADD

# %%
def ADD(a,b):
    return a + b

print(ADD(1,1))
# Out:
# 2

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item
#
# ***
#
# At the command prompt, type `def ADD(a,b):
#     return a + b`.
#
# ***
#
# [Google](https://www.google.com/)
#
# ***
#                 Name|Age|Adress|
#                 A|13| abc
#                 B|15| ab1
#                 C|16| ac2
